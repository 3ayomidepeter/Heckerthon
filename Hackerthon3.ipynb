# %% [markdown]
# <a href="https://colab.research.google.com/github/3ayomidepeter/Heckerthon/blob/main/Hackerthon3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## importing important library

# %%
#importing the libraries
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Loading Dataset

# %%
#load the various datasets
train=pd.read_csv("Train.csv")
test=pd.read_csv("Test.csv")
ss=pd.read_csv("SampleSubmission.csv")
var=pd.read_csv("VariableDefinitions.csv")

# %%
#preview the first five row of the train datasets
df=train.head()
df
# Out:
#   VehicleID Location          Maker                Model   Year  Colour  \
# 0  VHL12546    Abuja          Honda  Accord Coupe EX V-6  2,011  Silver
# 1  VHL18827   Ibadan        Hyundai               Sonata  2,012  Silver
# 2  VHL19499    Lagos          Lexus               RX 350  2,010     Red
# 3  VHL17991    Abuja  Mercedes-Benz            GLE-Class  2,017    Blue
# 4  VHL12170   Ibadan         Toyota           Highlander  2,002     Red
#
#    Amount (Million Naira)           Type Distance
# 0                     2.2  Nigerian Used      NaN
# 1                     3.5  Nigerian Used  125,000
# 2                     9.2   Foreign Used  110,852
# 3                    22.8   Foreign Used   30,000
# 4                     2.6  Nigerian Used  125,206

# %%
#preview the first five row of the test datasets
test.head()
# Out:
#   VehicleID Location   Maker                  Model   Year Colour  \
# 0  VHL18518    Abuja     BMW                   323i  2,008  White
# 1  VHL17149    Lagos  Toyota                  Camry  2,013  White
# 2  VHL10927    Lagos  Toyota  Highlander Limited V6  2,005   Gold
# 3  VHL12909    Lagos  Toyota                  Camry  2,011   Gray
# 4  VHL12348    Lagos   Lexus             ES 350 FWD  2,013    Red
#
#            Type  Distance
# 0  Foreign Used   30524.0
# 1  Foreign Used       NaN
# 2  Foreign Used       NaN
# 3  Foreign Used  166839.0
# 4  Foreign Used   88862.0

# %%
# get the shape of the train and test datasets
print(f"Train dataset shape is {train.shape}\nTest dataset shape is {test.shape}" )
# Out:
# Train dataset shape is (7205, 9)
# Test dataset shape is (2061, 8)

# %%
# get some information about  the data
display(train.info())

display(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7205 entries, 0 to 7204
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   VehicleID               7205 non-null   object
#  1   Location                7205 non-null   object
#  2   Maker                   7205 non-null   object
#  3   Model                   7205 non-null   object
#  4   Year                    7184 non-null   object
#  5   Colour                  7205 non-null   object
#  6   Amount (Million Naira)  7188 non-null   float64
#  7   Type                    7008 non-null   object
#  8   Distance                4845 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 506.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2061 entries, 0 to 2060
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
# ...

# %%
train.describe()
# Out:
#        Amount (Million Naira)
# count             7188.000000
# mean                11.847999
# std                 25.318922
# min                  0.450000
# 25%                  3.500000
# 50%                  5.650000
# 75%                 11.662500
# max                456.000000

# %%
test.describe()
# Out:
#             Distance
# count    1385.000000
# mean   103800.668592
# std    105986.234512
# min         1.000000
# 25%     52352.000000
# 50%     82000.000000
# 75%    120398.000000
# max    985216.000000

# %% [markdown]
# ## Cleaning the datasets

# %%
train.columns
# Out:
# Index(['VehicleID', 'Location', 'Maker', 'Model', 'Year', 'Colour',
#        'Amount (Million Naira)', 'Type', 'Distance'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['VehicleID', 'Location', 'Maker', 'Model', 'Year', 'Colour', 'Type',
#        'Distance'],
#       dtype='object')

# %%
#Checking for missing value
train.isnull().sum()
# Out:
# VehicleID                    0
# Location                     0
# Maker                        0
# Model                        0
# Year                        21
# Colour                       0
# Amount (Million Naira)      17
# Type                       197
# Distance                  2360
# dtype: int64

# %%
test.isnull().sum()
# Out:
# VehicleID      0
# Location       0
# Maker          0
# Model          0
# Year           2
# Colour         0
# Type          54
# Distance     676
# dtype: int64

# %%
#Filling missing value using mean for train
mean_value=train['Amount (Million Naira)'].mean()
print(mean_value)

train['Amount (Million Naira)'].fillna(mean_value, inplace=True)
# Out:
# 11.847999443516972

# %%
train.isnull().sum()
# Out:
# VehicleID                    0
# Location                     0
# Maker                        0
# Model                        0
# Year                        21
# Colour                       0
# Amount (Million Naira)       0
# Type                       197
# Distance                  2360
# dtype: int64

# %%
#dropping the vehicleID
train.drop(["VehicleID"], axis=1, inplace=True)
display(train.head())

test.drop(["VehicleID"], axis=1, inplace=True)
display(test.head())
# Out:
#   Location          Maker                Model   Year  Colour  \
# 0    Abuja          Honda  Accord Coupe EX V-6  2,011  Silver
# 1   Ibadan        Hyundai               Sonata  2,012  Silver
# 2    Lagos          Lexus               RX 350  2,010     Red
# 3    Abuja  Mercedes-Benz            GLE-Class  2,017    Blue
# 4   Ibadan         Toyota           Highlander  2,002     Red
#
#    Amount (Million Naira)           Type Distance
# 0                     2.2  Nigerian Used      NaN
# 1                     3.5  Nigerian Used  125,000
# 2                     9.2   Foreign Used  110,852
# 3                    22.8   Foreign Used   30,000
# 4                     2.6  Nigerian Used  125,206
#   Location   Maker                  Model   Year Colour          Type  \
# 0    Abuja     BMW                   323i  2,008  White  Foreign Used
# 1    Lagos  Toyota                  Camry  2,013  White  Foreign Used
# 2    Lagos  Toyota  Highlander Limited V6  2,005   Gold  Foreign Used
# ...

# %%
#label encoding

from sklearn.preprocessing import LabelEncoder

onehotencoder = LebelEncoder()
label_Location = pd.Dataframe(train, columns=["Location"])
label_Maker= pd.Dataframe(train, columns=["Maker"])
label_Model = pd.Dataframe(train, columns=["Model"])
label_Year = pd.Dataframe(train, columns=["Year"])
label_Colour = pd.Dataframe(train, columns=["Colour"])
label_Type = pd.Dataframe(train, columns=["Type"])
label_Distance = pd.Dataframe(train, columns=["Distance"])


train["Location"] = onehotcoder.fit_transform(train["Location"])
train["Maker"] = onehotcoder.fit_transform(train["Maker"])
train["Model"] = onehotcoder.fit_transform(train["Model"])
train["Year"] = onehotcoder.fit_transform(train["Year"])
train["Colour"] = onehotcoder.fit_transform(train["Colour"])
train["Type"] = onehotcoder.fit_transform(train["Type"])
train["Distance"] = onehotcoder.fit_transform(train["Distance"])

train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6c18db65c12b> in <cell line: 5>()
#       3 from sklearn.preprocessing import LabelEncoder
#       4
# ----> 5 onehotencoder = LebelEncoder()
#       6 label_Location = pd.Dataframe(train, columns=["Location"])
#       7 label_Maker= pd.Dataframe(train, columns=["Maker"])
#
# NameError: name 'LebelEncoder' is not defined
